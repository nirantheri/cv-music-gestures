# %%
# Most of the functionality will take place in your .py file, but we need a few libraries here
import torch
import matplotlib.pyplot as plt
# import numpy as np
# import torchvision.utils as tutils
import model_training
# import os

# %matplotlib inline
plt.rcParams['figure.figsize'] = [16, 10]

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# 2025-11-18 21:22:27.858651: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
data_dir = '/cs/cs153/datasets/gesture_data' # this line assumes you are working from the CS servers.

dataloader_v1, datadict = model_training.build_dataloader(data_dir, version = 1)

# %%
model1_dict = model_training.setup_simple_model(datadict, "1", device)
model2_dict = model_training.setup_simple_model(datadict, "2", device)
model3_dict = model_training.setup_model(datadict, device)

# model1_dict, log1 = model_training.train_model(model1_dict, dataloader_v1, datadict, device)
print(model1_dict["model"])
# Out:
# Classifier(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): LazyLinear(in_features=0, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=9, bias=True)
# )

# %%
model1_dict, log1 = model_training.train_model(model1_dict, dataloader_v1, datadict, device)
model2_dict, log2 = model_training.train_model(model2_dict, dataloader_v1, datadict, device)
# Out:
# Epoch 0/14
# ----------
#   0%|          | 266/67262 [00:02<12:11, 91.57it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # model1_dict, log1 = m1.train_model(model1_dict, dataloader_v1, datadict, device)
# ----> 2 model2_dict, log2 = model_training.train_model(model2_dict, dataloader_v1, datadict, device)
#
# File ~/courses/cs153/cv-music-gestures/model_training.py:268, in train_model(model_dict, dataloaders, datadict, device, num_epochs)
#     265 running_corrects = 0
#     267 # Iterate over data.
# --> 268 for inputs, labels in tqdm(dataloaders[phase]):
#     269     inputs = inputs.to(device)
#     270     labels = labels.to(device)
#
# File /mnt/cs/cs153/customenvs/music_prod/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
# ...
